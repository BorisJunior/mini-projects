# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('basket.csv')
df.head()
# Out:
#              0                   1                    2       3    4    5  \
# 0   whole milk              pastry          salty snack     NaN  NaN  NaN
# 1      sausage          whole milk  semi-finished bread  yogurt  NaN  NaN
# 2         soda  pickled vegetables                  NaN     NaN  NaN  NaN
# 3  canned beer     misc. beverages                  NaN     NaN  NaN  NaN
# 4      sausage    hygiene articles                  NaN     NaN  NaN  NaN
#
#      6    7    8    9   10
# 0  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN

# %%
df.fillna('!',inplace=True)
trans = df.values.tolist()

# %%
for i in range(len(trans)):
    trans[i] = [x for x in trans[i] if not x=='!']

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(trans).transform(trans)
transactions = pd.DataFrame(te_ary, columns=te.columns_)

# %%
freq_items = apriori(transactions, min_support=0.001, use_colnames=True, verbose=1)
freq_items.head(7)
# Out:
# Processing 28 combinations | Sampling itemset size 4e 3
#     support                 itemsets
# 0  0.004010  (Instant food products)
# 1  0.021386               (UHT-milk)
# 2  0.001470       (abrasive cleaner)
# 3  0.001938       (artif. sweetener)
# 4  0.008087          (baking powder)
# 5  0.001136       (bathroom cleaner)
# 6  0.033950                   (beef)

# %%
freq_items['length'] = freq_items['itemsets'].apply(lambda x: len(x))

# %%
freq_items.sort_values('length',ascending=False)
# Out:
#       support                                    itemsets  length
# 749  0.001470               (whole milk, yogurt, sausage)       3
# 745  0.001136           (whole milk, rolls/buns, sausage)       3
# 742  0.001203  (whole milk, rolls/buns, other vegetables)       3
# 743  0.001136        (whole milk, soda, other vegetables)       3
# 744  0.001136      (whole milk, yogurt, other vegetables)       3
# ..        ...                                         ...     ...
# 100  0.007819                                (pot plants)       1
# 99   0.037091                                      (pork)       1
# 98   0.003208                                   (popcorn)       1
# 97   0.049054                                 (pip fruit)       1
# 0    0.004010                     (Instant food products)       1
#
# [750 rows x 3 columns]

# %%
rules = association_rules(freq_items, metric="confidence", min_threshold=0.001)
rules.head()
# Out:
#           antecedents         consequents  antecedent support  \
# 0     (bottled water)          (UHT-milk)            0.060683
# 1          (UHT-milk)     (bottled water)            0.021386
# 2  (other vegetables)          (UHT-milk)            0.122101
# 3          (UHT-milk)  (other vegetables)            0.021386
# 4        (rolls/buns)          (UHT-milk)            0.110005
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.021386  0.001069    0.017621  0.823954 -0.000228    0.996168
# 1            0.060683  0.001069    0.050000  0.823954 -0.000228    0.988755
# 2            0.021386  0.002139    0.017515  0.818993 -0.000473    0.996060
# 3            0.122101  0.002139    0.100000  0.818993 -0.000473    0.975443
# 4            0.021386  0.001804    0.016403  0.767013 -0.000548    0.994934
#
#    zhangs_metric
# 0      -0.185312
# 1      -0.179204
# 2      -0.201119
# 3      -0.184234
# 4      -0.254457

# %%
rules.sort_values('confidence', ascending=False)
# Out:
#                 antecedents           consequents  antecedent support  \
# 1234      (yogurt, sausage)          (whole milk)            0.005748
# 1210  (rolls/buns, sausage)          (whole milk)            0.005347
# 1228        (soda, sausage)          (whole milk)            0.005948
# 1109  (semi-finished bread)          (whole milk)            0.009490
# 1222   (yogurt, rolls/buns)          (whole milk)            0.007819
# ...                     ...                   ...                 ...
# 958            (whole milk)               (pasta)            0.157923
# 654            (whole milk)         (frozen fish)            0.157923
# 1020           (whole milk)          (pot plants)            0.157923
# 982            (whole milk)  (pickled vegetables)            0.157923
# 1217           (whole milk)    (rolls/buns, soda)            0.157923
#
#       consequent support   support  confidence      lift  leverage  \
# 1234            0.157923  0.001470    0.255814  1.619866  0.000563
# 1210            0.157923  0.001136    0.212500  1.345594  0.000292
# 1228            0.157923  0.001069    0.179775  1.138374  0.000130
# 1109            0.157923  0.001671    0.176056  1.114825  0.000172
# 1222            0.157923  0.001337    0.170940  1.082428  0.000102
# ...                  ...       ...         ...       ...       ...
# 958             0.008087  0.001069    0.006771  0.837316 -0.000208
# 654             0.006817  0.001069    0.006771  0.993287 -0.000007
# 1020            0.007819  0.001002    0.006348  0.811821 -0.000232
# 982             0.008955  0.001002    0.006348  0.708829 -0.000412
# 1217            0.008087  0.001002    0.006348  0.784984 -0.000275
#
#       conviction  zhangs_metric
# 1234    1.131541       0.384877
# 1210    1.069304       0.258214
# 1228    1.026642       0.122281
# 1109    1.022008       0.103985
# 1222    1.015701       0.076751
# ...          ...            ...
# 958     0.998675      -0.187474
# 654     0.999954      -0.007962
# 1020    0.998519      -0.215852
# 982     0.997376      -0.327873
# 1217    0.998250      -0.245443
#
# [1238 rows x 10 columns]
