# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("p", attrs={"class":'legende'})
            
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("span", attrs={'class':'dyn_prod_price product__price--new'}).string.strip()

    except AttributeError:

        try:
            # If there is some deal price
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

        except:
            price = ""

    return price


# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("a", attrs={'href':'#com'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("p", attrs={'class':'dyn_prod_avaibility product__stock product__stock--stock'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"	

    return available

# %%
if __name__ == '__main__':

    # add your user agent 
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'})

    # The webpage URL
    URL = "https://www.rueducommerce.fr/r/telephones.html"

    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'item__image'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[], "reviews":[],"availability":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.rueducommerce.fr" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        d['availability'].append(get_availability(new_soup))

    
    rueducommerce = pd.DataFrame.from_dict(d)
    rueducommerce['title'].replace('', np.nan, inplace=True)
    rueducommerce = rueducommerce.dropna(subset=['title'])
    rueducommerce.to_csv("rueducommerce_data.csv", header=True, index=False)

# %%
new_soup
# Out:
# <!DOCTYPE html>
#
# <html id="rdc" lang="fr">
# <head>
# <title>Fisher Price - LE TELEPHONE ANIME - FGW66 - Jeux d'éveil - Rue du Commerce</title>
# <meta charset="utf-8"/>
# <meta content="Achetez votre Fisher Price LE TELEPHONE ANIME - FGW66 et retrouvez toute la selection de Jeux d'éveil Fisher Price sur Rue du Commerce au meilleur prix." name="description"/>
# <meta content="width=device-width, initial-scale=1, user-scalable=0" name="viewport"/>
# <meta content="Rue du commerce, hightech, high-tech, ordinateur, maison connectee, objet connecte, informatique, gaming, telephone, meubles, petit electromenager, jardin, pack location, pack revente" name="keywords"/>
# <meta content="max-image-preview:large" name="robots"/>
# <meta content="PQQOAbxOqmKoz0GP_75unXw0PPo7eD39WzxkAcj-4w0" name="google-site-verification">
# <meta content="ycaWidt1t6sfnwRYevEg41yKv2LP3D6V6RJBpEiEDiU" name="google-site-verification">
# <meta content="Achetez votre Fisher Price LE TELEPHONE ANIME - FGW66 et retrouvez toute la selection de Jeux d'éveil Fisher Price sur Rue du Commerce au meilleur prix." property="og:description"/>
# <meta content="website" prefix="og: http://ogp.me/ns#" property="og:type"/>
# <meta content="https://www.rueducommerce.fr/medias/22bb3cf82fce3c20b03ff66c1f097ef6/p_1000x1000/0887961516449-fgw66-1.jpg" prefix="og: http://ogp.me/ns#" property="og:image"/>
# <meta content="Fisher Price - LE TELEPHONE ANIME - FGW66 - Jeux d'éveil - Rue du Commerce" prefix="og: http://ogp.me/ns#" property="og:title"/> <meta content="Achetez votre Fisher Price LE TELEPHONE ANIME - FGW66 et retrouvez toute la selection de Jeux d'éveil Fisher Price sur Rue du Commerce au meilleur prix." prefix="og: http://ogp.me/ns#" property="og:description"/> <meta content="https://www.rueducommerce.fr/produit/mattel-le-telephone-anime-fgw66-27679132" prefix="og: http://ogp.me/ns#" property="og:url"/>
# <meta content="https://www.rueducommerce.fr/images/rdc/logo.png" name="twitter:card"/>
# <meta content="@rueducommerce" name="twitter:site"/>
# <meta content="https://www.rueducommerce.fr/produit/mattel-le-telephone-anime-fgw66-27679132" name="twitter:domain"/> <meta content="Fisher Price - LE TELEPHONE ANIME - FGW66 - Jeux d'éveil - Rue du Commerce" name="twitter:title"/> <meta content="Achetez votre Fisher Price LE TELEPHONE ANIME - FGW66 et retrouvez toute la selection de Jeux d'éveil Fisher Price sur Rue du Commerce au meilleur prix." name="twitter:description"/> <meta content="https://www.rueducommerce.fr/medias/22bb3cf82fce3c20b03ff66c1f097ef6/p_1000x1000/0887961516449-fgw66-1.jpg" name="twitter:image"/>
# <link href="https://www.googleadservices.com" rel="preconnect"/>
# <link href="https://www.googletagmanager.com" rel="preconnect"/>
# <link as="font" crossorigin="" href="/fonts/fontawesome-webfont.woff2?v=4.3.0" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/fonts/roboto-black.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/fonts/roboto-regular.woff2" rel="preload" type="font/woff2"/>
# <link href="https://www.rueducommerce.fr/produit/mattel-le-telephone-anime-fgw66-27679132" rel="canonical">
# <meta content="index,follow" name="robots">
# <meta content="Rue du Commerce" property="og:site_name"/>
# <meta content="https://www.rueducommerce.fr/produit/mattel-le-telephone-anime-fgw66-27679132" property="og:url">
# <meta content="" property="og:locale">
# <meta content="product.item" property="og:type">
# <link href="https://www.rueducommerce.fr/build/css/rdc/product.css?id=30ddf7361d3b3e75480c9f655e8f42f4" media="all" rel="stylesheet" type="text/css"/>
# <link href="/favicon/rdc/favicon.png" rel="icon"/>
# <script src="https://www.rueducommerce.fr/esi/start.php"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
#
# dataLayer.push({"event":"productDetailView","env_template":"produit","env_language":"fr","page_cat_id":26239,"page_cat_nom":"Jeux d'éveil","offers_count":24,"classification":{"id":6447,"nom":"Jeux d'éveil","classification_meuble":0,"qte_max_panier":null,"classification_logistic_format_id":null,"sous_famille":"Jeux d'éveil","sous_famille_id":6447,"famille":"Jouets 1er âge","famille_id":2617,"univers":"Jeux et jouets","univers_id":1711,"departement":"RDC - Fashion","departement_id":1627},"promotion_code":"","product_mp":"MP-9F2E1M27679132","rate_average":4,"rate_count":1,"ecommerce":{"currencyCode":"EUR","detail":{"products":[{"name":"LE TELEPHONE ANIME - FGW66","id":3042020,"ecomm_prodid":3042020,"price":20.36,"brand":"Fisher Price","availability":true,"shipping_price":0,"ean":"0887961516449","ref_frs":"FISHER-PRICE-FGW66","page_cat_1_id":14965,"page_cat_1_nom":"Jeux & Jouets","page_cat_2_id":16221,"page_cat_2_nom":"Jouets 1er âge","page_cat_3_id":26239,"page_cat_3_nom":"Jeux d'éveil","shop_name":"2KINGS","shop_id":3379,"base_price":22.4,"is_promo":true}]}},"article_offer_id":29204124,"article_offer_quality":"neuf"})
# </script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.defer=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KV4GH4N');</script>
# <script defer="" src="https://www.rueducommerce.fr/build/js/rdc/new-all.js?id=5cc4d8135dbea6104c2dda93a28fef82"></script>
# <script defer="" src="https://www.rueducommerce.fr/build/js/rdc/new-product.js?id=381b0e97bbbfbbf647916dce056e6e33"></script>
# <script>
#     tc_params = [{"type":"produit_id","value":3042020}];
# </script>
# </meta></meta></meta></meta></link></meta></meta></head>
# <body class="lang--fr page-product">
# <header id="header">
# <div class="header-box">
# <div id="header-top__banner--logo">
# <a href="https://www.rueducommerce.fr">
# <img alt="Logo Rue Du Commerce" class="lazyload top" data-src="/images/rdc/new/Logo-RDC-1.svg" src="/images/all/pixel.png"/>
# <img alt="Logo Rue Du Commerce" class="lazyload active" data-src="/images/rdc/new/RDC-Logomark-1_1-small.png" src="/images/all/pixel.png"/>
# <span>La Tech pour tous !</span>
# </a>
# </div>
# <div id="header-top__banner--search-box">
# <div>
# <div class="position">
# <div id="header-top__banner--search">
# <div>
# <form action="https://www.rueducommerce.fr/r/keyword.html" data-search="https://www.rueducommerce.fr/r/keyword.html" id="header__search" method="get">
# <meta content="https://www.rueducommerce.fr/r/{search_term_string}.html">
# <a id="search-close-btn"><i class="fa fa-times"></i></a>
# <input autocapitalize="off" autocomplete="off" autocorrect="off" class="apply-full-text-search" data-url="https://www.rueducommerce.fr/search" data-url-tracking="https://www.rueducommerce.fr/search/tracking" id="search-input" name="search_term_string" placeholder="Recherche" spellcheck="false" type="text" value=""/>
# <button aria-label="Valider" id="search_submit" type="submit">
# <img alt="Rechercher" class="lazyload" data-src="/images/rdc/new/icon-search.svg" src="/images/all/pixel.png"/>
# </button>
# </meta></form>
# <!-- Main -->
# <div id="header__search-result"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <ul id="header-top__right">
# <li class="block-inline--only-desktop" id="header-top__contact">
# <img alt="Contact" class="lazyload" data-src="/images/rdc/new/icon-headset.svg" src="/images/all/pixel.png"/>
# <div class="overlay__contact overlay__box">
# <div class="overlay__contact--divers">
# <a href="/page/aide-en-ligne-faq.html">Aide en ligne</a>
# <a href="/boutique/pro">Professionnel ?</a>
# <a href="https://www.rueducommerce.fr/contact_adv.html">Nous contacter</a>
# <p>Passer une commande ? Appelez le 0 892 46 56 66 (0.60€/min + prix appel)</p>
# </div>
# <div class="overlay__contact--commande">
# <a class="btn btn--prin btn--full-width" href="https://www.rueducommerce.fr/account_commande_last.html">Suivi de commande</a>
# </div>
# </div>
# </li>
# <li id="header-top__wishlist">
# <p class="h6">
# <a href="https://www.rueducommerce.fr/wishlist.html" rel="nofollow" title="Wishlist">
# <img alt="Wishlist" class="lazyload" data-src="/images/rdc/new/icon-heart.svg" src="/images/all/pixel.png"/>
# <span id="header-wishlist-count">0</span>
# </a>
# </p>
# <div class="overlay__account overlay__box">
# <p>Articles sauvegardés pour votre prochaine visite</p>
# </div>
# </li>
# <li class="block-inline--only-desktop" id="header-top__account">
# <p class="h6">
# <a href="https://www.rueducommerce.fr/account.html">
# <img alt="Mon compte" class="lazyload" data-src="/images/rdc/new/icons-user.svg" src="/images/all/pixel.png"/>
# <span id="header-email-count">0</span>
# </a>
# <div class="overlay__account overlay__box">
# <p>Retrouvez vos produits et votre espace client personnalisé :</p>
# <p>
# <a class="btn btn--prin btn--full-width" href="/login.html">Identifiez-vous</a>
# </p>
# <p>
# 								Pas encore membre ? <a href="/login.html?crea=1">créez votre compte</a>
# </p>
# </div>
# </p>
# <div class="overlay__account" hidden="" id="overlay__account_auth">
# <p class="h2-like">Bonjour <span id="overlay__account_auth_firstname"></span></p>
# <ul>
# <li><a href="/account_history.html">Consulter mes commandes</a></li>
# <li><a href="/messages.html">Consulter mes messages</a></li>
# <li><a href="/account_modify_id.html">Modifier mon mot de passe</a></li>
# <li><a href="/account_modify.html">Modifier mes informations</a></li>
# <li><a href="/account.html">Accéder à mon compte</a></li>
# </ul>
# <a class="btn btn--prin" href="/logout.html">
# 		Déconnexion
# 	</a>
# </div>
# </li>
# <li class="block-inline--only-nomad">
# <p class="h6">
# <a href="https://www.rueducommerce.fr/account.html">
# <img alt="Mon compte" class="lazyload" data-src="/images/rdc/new/icons-user.svg" src="/images/all/pixel.png"/>
# </a>
# </p>
# </li>
# <li id="header-top__cart">
# <p class="h6">
# <a href="https://www.rueducommerce.fr/shopping_cart.html">
# <img alt="Mon panier" class="lazyload" data-src="/images/rdc/new/icons-shopping-cart.svg" src="/images/all/pixel.png"/>
# </a>
# <a href="https://www.rueducommerce.fr/shopping_cart.html" rel="nofollow" title="Panier">
# <span class="number" id="header-top__cart-number"></span>
# </a>
# </p>
# <div class="overlay__cart overlay__box"></div>
# </li>
# </ul>
# <div class="secure">
# <svg aria-hidden="true" fill="#666" height="27" viewbox="0 0 30 30" width="27">
# <path d="M21.831 11.922V7.477C21.831 3.905 18.958 1 15.427 1c-3.532 0-6.405 2.906-6.405 6.477v4.444h-4.27v11.302c0 3.023 2.613 5.777 5.481 5.777h10.122c3.062 0 4.892-2.937 4.892-5.777V11.921zM10.73 7.477c0-2.674 2.063-4.769 4.697-4.769 2.633 0 4.696 2.096 4.696 4.77v4.443H10.73V7.477zm12.809 15.746c0 2-1.191 4.07-3.184 4.07H10.234c-1.94 0-3.773-1.978-3.773-4.07V13.63H23.54zm-9.18-3.142v2.94a.853.853 0 1 0 1.708 0v-2.94a1.7 1.7 0 0 0 .855-1.47 1.708 1.708 0 0 0-3.416 0 1.7 1.7 0 0 0 .853 1.47z"></path>
# </svg>
# <span>Paiement sécurisé</span>
# </div>
# </div>
# <div class="block--mobile">
# <a class="header-nomad__btn" id="header-nomad__btn">
# <svg aria-hidden="true" height="34" width="23">
# <use xlink:href="#icon--burger">
# <symbol id="icon--burger" viewbox="0 0 26 26">
# <path d="M0 4.33h26v1.34H0zm0 8.2h26v1.34H0zm0 7.8h26v1.34H0z"></path>
# </symbol>
# </use>
# </svg> </a>
# <p id="header-mobile-tech">La Tech pour tous !</p>
# </div>
# </header>
# <nav id="menu">
# <div id="menu-box">
# <div data-url="https://www.rueducommerce.fr/menu/2136?desktop=1" data-url-proposition="https://www.rueducommerce.fr/ajax/proposition" id="nav-box">
# <div id="nav-new"><ul id="nav-new-root">
# <li class="nav-new-tab nav-new-tab-colored" id="nav-tab-1974">
# <a class="main-menu-link nav-new-tab-link nav-new-tab-bold" href="/boutique/soldes">SOLDES ETE</a>
# <div class="nav-new-tab-content">
# <div class="nav-new-row" id="nav-line-1975">
# <div class="nav-new-column nav-new-column-100" id="nav-column-1976">
# <div class="nav-new-title" id="nav-title-1977">
# <a class="main-menu-link" href="/boutique/soldes">SOLDES D'ETE 2023</a>
# </div>
# <hr id="nav-separator-1978"/>
# </div>
# <div class="nav-new-column nav-new-column-25" id="nav-column-1979">
# <div class="nav-new-list-title" id="nav-list-1980">
# <a class="main-menu-link" href="/boutique/soldes">Nos top catégories</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-1981">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/soldes?filtre=g-25476">
#                 Ordinateurs
#             </a>
# </li>
# <li id="nav-list-link-1982">
# <a class="main-menu-link" href="/rayon/composants-16/soldes?filtre=g-25476">
#                 Composants
#             </a>
# </li>
# <li id="nav-list-link-1983">
# <a class="main-menu-link" href="/rayon/telephonie-92/smartphone-821/soldes">
#                 Smartphone
#             </a>
# </li>
# <li id="nav-list-link-1984">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/tv-led-802/soldes?filtre=g-25476">
#                 TV
#             </a>
# </li>
# <li id="nav-list-link-2000">
# <a class="main-menu-link" href="/rayon/soldes-bonnes-affaires-objets-connectes">
#                 Objets connectés
#             </a>
# </li>
# <li id="nav-list-link-1985">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/siege-gamer-7000/soldes?filtre=g-25476">
#                 Siège gamer
#             </a>
# </li>
# <li id="nav-list-link-1986">
# <a class="main-menu-link" href="/rayon/electromenager-26/soldes">
#                 Electroménager
#             </a>
# </li>
# <li id="nav-list-link-1987">
# <a class="main-menu-link" href="/rayon/maison-52/soldes-et-bonnes-affaires-maison-111332">
#                 Maison
#             </a>
# </li>
# </ul>
# </div>
# <div class="nav-new-column nav-new-column-25" id="nav-column-1988">
# <div class="nav-new-list-title" id="nav-list-1989">
# <a class="main-menu-link" href="/boutique/soldes">Nos top marques</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-1990">
# <a class="main-menu-link" href="/marque/asus/soldes">
#                 ASUS
#             </a>
# </li>
# <li id="nav-list-link-1995">
# <a class="main-menu-link" href="/marque/samsung/soldes">
#                 Samsung
#             </a>
# </li>
# <li id="nav-list-link-1991">
# <a class="main-menu-link" href="/marque/msi/soldes">
#                 MSI
#             </a>
# </li>
# <li id="nav-list-link-1992">
# <a class="main-menu-link" href="/marque/hp/soldes">
#                 HP
#             </a>
# </li>
# <li id="nav-list-link-1993">
# <a class="main-menu-link" href="/marque/corsair/soldes">
#                 Corsair
#             </a>
# </li>
# <li id="nav-list-link-1996">
# <a class="main-menu-link" href="/marque/xiaomi/soldes">
#                 Xiaomi
#             </a>
# </li>
# <li id="nav-list-link-1994">
# <a class="main-menu-link" href="/marque/apple/soldes">
#                 Apple
#             </a>
# </li>
# </ul>
# </div>
# <div class="nav-new-column nav-new-column-50 nav-new-column-center" id="nav-column-1997">
# <p class="nav-new-text" id="nav-text-1998">La 1ère démarque des soldes d'été 2023 commence !</p>
# <a class="main-menu-link nav-new-image-link" href="/rayon/soldes-9434">
# <img alt="Soldes été 2023" class="nav-new-image lazyload nav-new-image-rounded-border" data-src="/media/new-menu/rue-du-commerce/2136/soldes-ete-2023-int-1792x400.png" id="nav-image-1999" src="/images/all/pixel.png" title="Soldes été 2023"/>
# </a>
# </div>
# <div class="nav-new-clear"></div>
# </div>
# </div>
# </li>
# <li class="nav-new-tab nav-new-tab-default" id="nav-tab-67">
# <a class="main-menu-link nav-new-tab-link" href="/vitrine/informatique">INFORMATIQUE</a>
# <div class="nav-new-tab-content">
# <div class="nav-new-row" id="nav-line-74">
# <div class="nav-new-column nav-new-column-100" id="nav-column-1077">
# <div class="nav-new-title" id="nav-title-1079">
# <a class="main-menu-link" href="/vitrine/informatique">INFORMATIQUE</a>
# </div>
# <hr id="nav-separator-1078"/>
# </div>
# <div class="nav-new-column nav-new-column-25" id="nav-column-75">
# <div class="nav-new-list-title" id="nav-list-77">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/ordinateur-portable-657">ORDINATEUR PORTABLE</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-711">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/pc-portable-gamer-8032">
#                 PC Portable Gamer
#             </a>
# </li>
# <li id="nav-list-link-417">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/pc-ultraportable-18704">
#                 Ultrabook - Ultraportable
#             </a>
# </li>
# <li id="nav-list-link-416">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/pc-portable-5875">
#                 PC Portable bureautique
#             </a>
# </li>
# <li id="nav-list-link-415">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/macbook-8022">
#                 Macbook
#             </a>
# </li>
# <li id="nav-list-link-419">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/chromebook-61814">
#                 Chromebook
#             </a>
# </li>
# <li id="nav-list-link-427">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/pc-portable-creator-100557">
#                 PC Creator
#             </a>
# </li>
# <li id="nav-list-link-764">
# <a class="main-menu-link nav-new-list-link-bold nav-new-link-color-green-heavy" href="/rayon/destockage-22/ordinateur-portable-2721">
#                 Seconde vie - PC Portable
#             </a>
# </li>
# <li id="nav-list-link-858">
# <a class="main-menu-link nav-new-list-link-bold nav-new-link-color-green-light" href="/rayon/pc-portable-location">
#                 Louez votre PC Portable
#             </a>
# </li>
# </ul>
# <div class="nav-new-list-title" id="nav-list-428">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/ordinateur-de-bureau-658">ORDINATEUR DE BUREAU</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-712">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/pc-fixe-gamer-5877">
#                 PC Fixe Gamer
#             </a>
# </li>
# <li id="nav-list-link-792">
# <a class="main-menu-link nav-new-list-link-bold" href="/rayon/composants-16/pc-montes-28449">
#                 PC monté by RDC
#             </a>
# </li>
# <li id="nav-list-link-431">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/ordinateur-tout-en-un-11040">
#                 PC tout-en-un
#             </a>
# </li>
# <li id="nav-list-link-430">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/pc-fixe-5878">
#                 PC Fixe bureautique
#             </a>
# </li>
# <li id="nav-list-link-429">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/mac-et-imac-5876">
#                 iMac - Mac mini - Mac pro
#             </a>
# </li>
# <li id="nav-list-link-861">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/mini-pc-12598">
#                 Mini PC
#             </a>
# </li>
# <li id="nav-list-link-765">
# <a class="main-menu-link nav-new-list-link-bold nav-new-link-color-green-heavy" href="/rayon/destockage-22/pc-reconditionne-11522">
#                 Seconde vie - PC Fixe
#             </a>
# </li>
# <li id="nav-list-link-863">
# <a class="main-menu-link nav-new-list-link-bold nav-new-link-color-green-light" href="/rayon/pc-fixe-location">
#                 Louez votre PC Fixe
#             </a>
# </li>
# </ul>
# </div>
# <div class="nav-new-column nav-new-column-25" id="nav-column-76">
# <div class="nav-new-list-title" id="nav-list-432">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/ecran-717">ECRAN PC</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-864">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/ecran-gamer-100235">
#                 Ecran PC Gamer
#             </a>
# </li>
# <li id="nav-list-link-865">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/ecran-717/utilisation:bureautique">
#                 Ecran PC bureautique
#             </a>
# </li>
# <li id="nav-list-link-1004">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/ecran-pc-4k-13118">
#                 Ecran PC 4K
#             </a>
# </li>
# <li id="nav-list-link-866">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/support-ecran-bureau">
#                 Support Ecran PC
#             </a>
# </li>
# </ul>
# <div class="nav-new-list-title" id="nav-list-450">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73">PERIPHERIQUES - ACCESSOIRES</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-451">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/clavier-souris-tapis-de-souris">
#                 Clavier - Souris - Tapis de souris
#             </a>
# </li>
# <li id="nav-list-link-1796">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/siege-gamer-7000">
#                 Chaise Gamer
#             </a>
# </li>
# <li id="nav-list-link-453">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/webcam-micro-casque-729">
#                 Casque micro
#             </a>
# </li>
# <li id="nav-list-link-723">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/webcam-102363">
#                 Webcam
#             </a>
# </li>
# <li id="nav-list-link-454">
# <a class="main-menu-link" href="/rayon/accessoires-et-consommables-2/cable-et-connectique-137">
#                 Câble - Connectique
#             </a>
# </li>
# <li id="nav-list-link-869">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/tablette-graphique-6247">
#                 Tablette graphique
#             </a>
# </li>
# <li id="nav-list-link-842">
# <a class="main-menu-link" href="/boutique/sumup">
#                 Terminal de paiement SumUp
#             </a>
# </li>
# </ul>
# <div class="nav-new-list-title" id="nav-list-455">
# <a class="main-menu-link" href="/rayon/composants-16/stockage-8034">STOCKAGE</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-457">
# <a class="main-menu-link" href="/rayon/composants-16/disque-dur-externe-1948">
#                 Disque dur externe
#             </a>
# </li>
# <li id="nav-list-link-459">
# <a class="main-menu-link" href="/rayon/composants-16/carte-memoire-234">
#                 Carte mémoire
#             </a>
# </li>
# <li id="nav-list-link-460">
# <a class="main-menu-link" href="/rayon/composants-16/cle-usb-235">
#                 Clé USB
#             </a>
# </li>
# </ul>
# </div>
# <div class="nav-new-column nav-new-column-25" id="nav-column-444">
# <div class="nav-new-list-title" id="nav-list-461">
# <a class="main-menu-link" href="/vitrine/composants">COMPOSANT</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-463">
# <a class="main-menu-link" href="/rayon/composants-16/carte-graphique-231">
#                 Carte graphique
#             </a>
# </li>
# <li id="nav-list-link-464">
# <a class="main-menu-link" href="/rayon/composants-16/carte-mere-232">
#                 Carte mère
#             </a>
# </li>
# <li id="nav-list-link-466">
# <a class="main-menu-link" href="/rayon/composants-16/memoire-pc-245">
#                 RAM PC
#             </a>
# </li>
# <li id="nav-list-link-465">
# <a class="main-menu-link" href="/rayon/composants-16/processeur-246">
#                 Processeur
#             </a>
# </li>
# <li id="nav-list-link-467">
# <a class="main-menu-link" href="/rayon/composants-16/kit-d-evolution-242">
#                 Kit d'évolution
#             </a>
# </li>
# <li id="nav-list-link-471">
# <a class="main-menu-link" href="/rayon/composants-16/watercooling-250">
#                 Watercooling
#             </a>
# </li>
# <li id="nav-list-link-470">
# <a class="main-menu-link" href="/rayon/composants-16/ventirad">
#                 Ventirad
#             </a>
# </li>
# <li id="nav-list-link-872">
# <a class="main-menu-link" href="/rayon/composants-16/ssd-248">
#                 SSD M.2 - SSD
#             </a>
# </li>
# <li id="nav-list-link-871">
# <a class="main-menu-link" href="/rayon/composants-16/disque-dur-236">
#                 Disque dur
#             </a>
# </li>
# <li id="nav-list-link-469">
# <a class="main-menu-link" href="/rayon/composants-16/boitier-pc-1900">
#                 Boitier PC
#             </a>
# </li>
# <li id="nav-list-link-468">
# <a class="main-menu-link" href="/rayon/composants-16/alimentation-pc-226">
#                 Alimentation PC
#             </a>
# </li>
# <li id="nav-list-link-873">
# <a class="main-menu-link" href="/rayon/composants-16/ventilateur-pour-boitier-1997">
#                 Ventilateur Boîtier
#             </a>
# </li>
# <li id="nav-list-link-874">
# <a class="main-menu-link" href="/rayon/composants-16/pate-thermique-1984">
#                 Pâte thermique
#             </a>
# </li>
# <li id="nav-list-link-875">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/carte-reseau-6274">
#                 Carte réseau
#             </a>
# </li>
# <li id="nav-list-link-767">
# <a class="main-menu-link nav-new-list-link-bold nav-new-link-color-green-heavy" href="/rayon/destockage-22/composants-301">
#                 Seconde vie - Composant
#             </a>
# </li>
# </ul>
# <div class="nav-new-list-title" id="nav-list-678">
# <a class="main-menu-link" href="/rayon/logiciels-49">LOGICIEL</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-859">
# <a class="main-menu-link" href="/rayon/logiciels-49?fournisseur=microsoft">
#                 Microsoft Office
#             </a>
# </li>
# <li id="nav-list-link-860">
# <a class="main-menu-link" href="/rayon/logiciels-49/antivirus-et-securite-523">
#                 Antivirus - Sécurité
#             </a>
# </li>
# </ul>
# </div>
# <div class="nav-new-column nav-new-column-25" id="nav-column-462">
# <div class="nav-new-list-title" id="nav-list-437">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/reseaux-723">RESEAU</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-438">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/modem-routeur-points-d-acces-6275">
#                 Modem - Routeur - Point d’accès
#             </a>
# </li>
# <li id="nav-list-link-439">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/repeteur-wifi-cpl">
#                 Répéteur Wifi - CPL
#             </a>
# </li>
# <li id="nav-list-link-440">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/onduleur-6278">
#                 Onduleur - Multiprise
#             </a>
# </li>
# <li id="nav-list-link-442">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/switch-6280">
#                 Switch
#             </a>
# </li>
# <li id="nav-list-link-867">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/nas-6277">
#                 NAS
#             </a>
# </li>
# <li id="nav-list-link-868">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/carte-reseau-6274">
#                 Carte réseau
#             </a>
# </li>
# </ul>
# <div class="nav-new-list-title" id="nav-list-473">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/imprimantes-et-scanners-720">IMPRIMANTE - SCANNER</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-474">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/imprimante-jet-d-encre-6259">
#                 Imprimante jet d’encre
#             </a>
# </li>
# <li id="nav-list-link-475">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/imprimante-laser-6260">
#                 Imprimante laser
#             </a>
# </li>
# <li id="nav-list-link-726">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/imprimante-3d-6258">
#                 Imprimante 3D
#             </a>
# </li>
# <li id="nav-list-link-476">
# <a class="main-menu-link" href="/rayon/accessoires-et-consommables-2/cartouche-d-encre-1253">
#                 Cartouche d’encre
#             </a>
# </li>
# <li id="nav-list-link-477">
# <a class="main-menu-link" href="/rayon/accessoires-et-consommables-2/toner-1302">
#                 Toner
#             </a>
# </li>
# </ul>
# <div class="nav-new-list-title" id="nav-list-1747">
# <a class="main-menu-link" href="/vitrine/informatique">NOS COUPS DE COEUR</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-1750">
# <a class="main-menu-link" href="/boutique/nvidia-studio">
#                 Nvidia Studio
#             </a>
# </li>
# <li id="nav-list-link-1751">
# <a class="main-menu-link" href="/boutique/intel-evo">
#                 Intel Evo
#             </a>
# </li>
# <li id="nav-list-link-1748">
# <a class="main-menu-link" href="/rayon/teletravail-116799">
#                 Univers Télétravail
#             </a>
# </li>
# <li id="nav-list-link-1749">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/materiel-streaming-727">
#                 Univers Streaming
#             </a>
# </li>
# <li id="nav-list-link-1901">
# <a class="main-menu-link nav-new-list-link-bold nav-new-link-color-green-heavy" href="/rayon/destockage-22/informatique">
#                 &gt; SECONDE VIE INFORMATIQUE
#             </a>
# </li>
# </ul>
# </div>
# <div class="nav-new-clear"></div>
# </div>
# </div>
# </li>
# <li class="nav-new-tab nav-new-tab-default" id="nav-tab-144">
# <a class="main-menu-link nav-new-tab-link" href="/vitrine/gaming">GAMING</a>
# <div class="nav-new-tab-content">
# <div class="nav-new-row" id="nav-line-478">
# <div class="nav-new-column nav-new-column-100" id="nav-column-1073">
# <div class="nav-new-title" id="nav-title-1076">
# <a class="main-menu-link" href="/vitrine/gaming">GAMING</a>
# </div>
# <hr id="nav-separator-1074"/>
# </div>
# <div class="nav-new-column nav-new-column-25 nav-new-margin-0 nav-new-column-left" id="nav-column-479">
# <div class="nav-new-list-title" id="nav-list-1015">
# <a class="main-menu-link" href="/rayon/nos-teammates">NOS TEAMMATES</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-1016">
# <a class="main-menu-link" href="/boutique/msi">
#                 MSI
#             </a>
# </li>
# <li id="nav-list-link-1017">
# <a class="main-menu-link" href="/boutique/rog">
#                 ASUS ROG
#             </a>
# </li>
# <li id="nav-list-link-1019">
# <a class="main-menu-link" href="/boutique/nvidia">
#                 NVIDIA
#             </a>
# </li>
# <li id="nav-list-link-1020">
# <a class="main-menu-link" href="/boutique/corsair">
#                 Corsair
#             </a>
# </li>
# <li id="nav-list-link-1022">
# <a class="main-menu-link" href="/boutique/omen">
#                 Omen - HyperX
#             </a>
# </li>
# </ul>
# <div class="nav-new-list-title" id="nav-list-480">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/pc-portable-gamer-8032">PC PORTABLE GAMER</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-481">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/pc-portable-geforce-rtx-62661">
#                 PC Portable Gamer RTX
#             </a>
# </li>
# <li id="nav-list-link-1830">
# <a class="main-menu-link" href="/rayon/pc-portable-nvidia-serie-40">
#                 PC Portable NVIDIA Série 40
#             </a>
# </li>
# <li id="nav-list-link-492">
# <a class="main-menu-link" href="/rayon/accessoires-et-consommables-2/sacoche-housse-et-sac-a-dos-pour-ordinateur-portable-1232">
#                 Sacoche PC portable
#             </a>
# </li>
# <li id="nav-list-link-770">
# <a class="main-menu-link nav-new-list-link-bold nav-new-link-color-green-heavy" href="/rayon/ordinateurs-64/pc-portable-gamer-8032/occasions">
#                 Seconde vie - PC Portable Gamer
#             </a>
# </li>
# </ul>
# <div class="nav-new-list-title" id="nav-list-498">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/ecran-gamer-100235">ECRAN PC GAMER</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-1044">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/ecran-gamer-100235/grand-format">
#                 Grand format
#             </a>
# </li>
# <li id="nav-list-link-1045">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/support-ecran-bureau">
#                 Support écran PC
#             </a>
# </li>
# </ul>
# </div>
# <div class="nav-new-column nav-new-column-25 nav-new-column-left" id="nav-column-493">
# <div class="nav-new-list-title" id="nav-list-494">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/pc-fixe-gamer-5877">PC FIXE GAMER</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-793">
# <a class="main-menu-link" href="/rayon/composants-16/pc-montes-28449">
#                 PC monté by RDC
#             </a>
# </li>
# <li id="nav-list-link-495">
# <a class="main-menu-link" href="/rayon/ordinateurs-64/pc-fixe-gamer-equipes-nvidia-rtx-107116">
#                 PC Fixe Gamer RTX
#             </a>
# </li>
# <li id="nav-list-link-1801">
# <a class="main-menu-link" href="/boutique/powered-by-msi">
#                 PC Monté powered by MSI
#             </a>
# </li>
# </ul>
# <div class="nav-new-list-title" id="nav-list-1025">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/peripheriques-gamer-8036">SETUP GAMING</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-1029">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/clavier-6244/utilisation:gamer">
#                 Clavier Gamer
#             </a>
# </li>
# <li id="nav-list-link-1030">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/souris-tapis/usage:gamer">
#                 Souris - Tapis de souris Gamer
#             </a>
# </li>
# <li id="nav-list-link-1032">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/micro-casque-6302">
#                 Casque micro
#             </a>
# </li>
# <li id="nav-list-link-1033">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/siege-bureau-gamer">
#                 Chaise - Bureau Gamer
#             </a>
# </li>
# <li id="nav-list-link-1038">
# <a class="main-menu-link" href="/rayon/accessoires-et-consommables-2/cable-et-connectique-137">
#                 Câble - Connectique
#             </a>
# </li>
# </ul>
# <div class="nav-new-list-title" id="nav-list-518">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/reseaux-723">RESEAUX</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-1058">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/modem-routeur-points-d-acces-6275">
#                 Modem - Routeur
#             </a>
# </li>
# <li id="nav-list-link-1059">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/switch-6280">
#                 Switch
#             </a>
# </li>
# <li id="nav-list-link-1060">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/onduleur-6278">
#                 Onduleur - Multiprise
#             </a>
# </li>
# </ul>
# </div>
# <div class="nav-new-column nav-new-column-25" id="nav-column-507">
# <div class="nav-new-list-title" id="nav-list-508">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/materiel-streaming-727">UNIVERS STREAMING</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-519">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/boitier-d-acquisition-102349">
#                 Boitier d'acquisition
#             </a>
# </li>
# <li id="nav-list-link-520">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/microphone-pc-102370">
#                 Microphone
#             </a>
# </li>
# <li id="nav-list-link-521">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/webcam-102363">
#                 Webcam
#             </a>
# </li>
# </ul>
# <div class="nav-new-list-title" id="nav-list-727">
# <a class="main-menu-link" href="/rayon/jeux-et-consoles-43">JEUX ET CONSOLES</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-1848">
# <a class="main-menu-link" href="/rayon/jeux-et-consoles-43/ps5">
#                 PS5
#             </a>
# </li>
# <li id="nav-list-link-1849">
# <a class="main-menu-link" href="/rayon/jeux-et-consoles-43/ps4-488">
#                 PS4
#             </a>
# </li>
# <li id="nav-list-link-1850">
# <a class="main-menu-link" href="/rayon/jeux-et-consoles-43/xbox-series">
#                 Xbox Series
#             </a>
# </li>
# <li id="nav-list-link-1851">
# <a class="main-menu-link" href="/rayon/jeux-et-consoles-43/nintendo-switch-491">
#                 Nintendo Switch
#             </a>
# </li>
# <li id="nav-list-link-1067">
# <a class="main-menu-link" href="/rayon/jeux-et-consoles-43/jeux-pc-et-accessoires-482">
#                 Jeux PC et accessoires
#             </a>
# </li>
# <li id="nav-list-link-1048">
# <a class="main-menu-link" href="/rayon/jeux-et-consoles-43/manettes">
#                 Manette
#             </a>
# </li>
# <li id="nav-list-link-1047">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/casque-de-realite-virtuelle-713">
#                 Casque VR
#             </a>
# </li>
# <li id="nav-list-link-1049">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/tout-le-materiel-pour-la-simulation-de-courses-automobiles-123197">
#                 Simulation course - Volant
#             </a>
# </li>
# <li id="nav-list-link-1050">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/joystick-6996">
#                 Simulation vol - Joystick
#             </a>
# </li>
# <li id="nav-list-link-768">
# <a class="main-menu-link nav-new-list-link-bold nav-new-link-color-green-heavy" href="/rayon/destockage-22/jeux-et-consoles-310">
#                 Seconde vie - Jeux et consoles
#             </a>
# </li>
# </ul>
# </div>
# <div class="nav-new-column nav-new-column-25" id="nav-column-523">
# <div class="nav-new-list-title" id="nav-list-524">
# <a class="main-menu-link" href="/vitrine/composants">COMPOSANT</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-525">
# <a class="main-menu-link" href="/rayon/composants-16/carte-graphique-231">
#                 Carte graphique
#             </a>
# </li>
# <li id="nav-list-link-526">
# <a class="main-menu-link" href="/rayon/composants-16/carte-mere-232">
#                 Carte mère
#             </a>
# </li>
# <li id="nav-list-link-528">
# <a class="main-menu-link" href="/rayon/composants-16/memoire-pc-245">
#                 RAM PC
#             </a>
# </li>
# <li id="nav-list-link-527">
# <a class="main-menu-link" href="/rayon/composants-16/processeur-246">
#                 Processeur
#             </a>
# </li>
# <li id="nav-list-link-529">
# <a class="main-menu-link" href="/rayon/composants-16/kit-d-evolution-242">
#                 Kit d’évolution
#             </a>
# </li>
# <li id="nav-list-link-534">
# <a class="main-menu-link" href="/rayon/composants-16/watercooling-250">
#                 Watercooling
#             </a>
# </li>
# <li id="nav-list-link-533">
# <a class="main-menu-link" href="/rayon/composants-16/ventirad">
#                 Ventirad
#             </a>
# </li>
# <li id="nav-list-link-532">
# <a class="main-menu-link" href="/rayon/composants-16/ssd-interne-1989">
#                 SSD M.2 - SSD
#             </a>
# </li>
# <li id="nav-list-link-1063">
# <a class="main-menu-link" href="/rayon/composants-16/disque-dur-236">
#                 Disque dur
#             </a>
# </li>
# <li id="nav-list-link-531">
# <a class="main-menu-link" href="/rayon/composants-16/boitier-pc-1900">
#                 Boitier PC
#             </a>
# </li>
# <li id="nav-list-link-530">
# <a class="main-menu-link" href="/rayon/composants-16/alimentation-pc-226">
#                 Alimentation PC
#             </a>
# </li>
# <li id="nav-list-link-1064">
# <a class="main-menu-link" href="/rayon/composants-16/ventilateur-pour-boitier-1997">
#                 Ventilateur boîtier
#             </a>
# </li>
# <li id="nav-list-link-1065">
# <a class="main-menu-link" href="/rayon/composants-16/pate-thermique-1984">
#                 Pâte thermique
#             </a>
# </li>
# <li id="nav-list-link-1066">
# <a class="main-menu-link" href="/rayon/peripheriques-reseaux-et-wifi-73/carte-reseau-6274">
#                 Carte réseau
#             </a>
# </li>
# <li id="nav-list-link-1903">
# <a class="main-menu-link nav-new-list-link-bold nav-new-link-color-green-heavy" href="/rayon/destockage-22/gaming">
#                 &gt; SECONDE VIE GAMING
#             </a>
# </li>
# </ul>
# </div>
# <div class="nav-new-clear"></div>
# </div>
# </div>
# </li>
# <li class="nav-new-tab nav-new-tab-default" id="nav-tab-66">
# <a class="main-menu-link nav-new-tab-link" href="/vitrine/image-et-son">TV - SON - PHOTO</a>
# <div class="nav-new-tab-content">
# <div class="nav-new-row" id="nav-line-295">
# <div class="nav-new-column nav-new-column-100" id="nav-column-1080">
# <div class="nav-new-title" id="nav-title-1081">
# <a class="main-menu-link" href="/vitrine/image-et-son">TV - SON - PHOTO</a>
# </div>
# <hr id="nav-separator-1082"/>
# </div>
# <div class="nav-new-column nav-new-column-25" id="nav-column-296">
# <div class="nav-new-list-title" id="nav-list-290">
# <a class="main-menu-link" href="/vitrine/tv-led">TELEVISEUR</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-291">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/tv-led-802/norme-d-affichage-tv:4k-uhd">
#                 TV 4K UHD
#             </a>
# </li>
# <li id="nav-list-link-294">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/tv-qled-samsung-98317">
#                 TV Samsung QLED
#             </a>
# </li>
# <li id="nav-list-link-297">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/tv-oled-lg-103959">
#                 TV LG OLED
#             </a>
# </li>
# <li id="nav-list-link-299">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/tv-philips-ambilight-75422">
#                 TV Philips Ambilight
#             </a>
# </li>
# <li id="nav-list-link-1005">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/tv-led-802/taille-d-ecran-tv-pouces:55">
#                 TV 55 pouces
#             </a>
# </li>
# <li id="nav-list-link-1006">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/tv-led-802/taille-d-ecran-tv-pouces:65">
#                 TV 65 pouces
#             </a>
# </li>
# <li id="nav-list-link-302">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/smart-tv-10740">
#                 Smart TV
#             </a>
# </li>
# <li id="nav-list-link-303">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/passerelle-multimedia-6661">
#                 Box multimédia
#             </a>
# </li>
# <li id="nav-list-link-896">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/support-meuble-tv-799">
#                 Support - Meuble TV
#             </a>
# </li>
# <li id="nav-list-link-772">
# <a class="main-menu-link nav-new-list-link-bold nav-new-link-color-green-heavy" href="/rayon/destockage-22/tv-led-113768">
#                 Seconde vie - Téléviseur
#             </a>
# </li>
# </ul>
# <div class="nav-new-list-title" id="nav-list-880">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/videoprojecteur-805">VIDEOPROJECTEUR</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-306">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/videoprojecteurs-portables-6663">
#                 Vidéoprojecteur portable
#             </a>
# </li>
# <li id="nav-list-link-881">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/ecran-de-projection-795">
#                 Ecran vidéoprojecteur
#             </a>
# </li>
# <li id="nav-list-link-882">
# <a class="main-menu-link" href="/rayon/tv-et-lecteurs-dvd-86/supports-de-plafond-videoprojecteur-6637">
#                 Support vidéoprojecteur
#             </a>
# </li>
# </ul>
# </div>
# <div class="nav-new-column nav-new-column-25" id="nav-column-309">
# <div class="nav-new-list-title" id="nav-list-310">
# <a class="main-menu-link" href="/vitrine/hifi">CASQUE - ECOUTEURS</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-887">
# <a class="main-menu-link nav-new-list-link-bold" href="/rayon/mp3-mp4-et-son-numerique-51/casque-4826">
#                 Casque
#             </a>
# </li>
# <li id="nav-list-link-312">
# <a class="main-menu-link" href="/rayon/mp3-mp4-et-son-numerique-51/casque-bluetooth-8974">
#                 Casque sans fil
#             </a>
# </li>
# <li id="nav-list-link-313">
# <a class="main-menu-link" href="/rayon/mp3-mp4-et-son-numerique-51/casque-reducteur-de-bruit-26831">
#                 Casque réducteur de bruit
#             </a>
# </li>
# <li id="nav-list-link-888">
# <a class="main-menu-link nav-new-list-link-bold" href="/rayon/mp3-mp4-et-son-numerique-51/ecouteurs-intra-auriculaires-11092">
#                 Ecouteurs
#             </a>
# </li>
# <li id="nav-list-link-311">
# <a class="main-menu-link" href="/rayon/mp3-mp4-et-son-numerique-51/airpods-81204">
#                 AirPods
#             </a>
# </li>
# <li id="nav-list-link-884">
# <a class="main-menu-link" href="/rayon/mp3-mp4-et-son-numerique-51/ecouteur-sans-fil-13228">
#                 Ecouteurs sans fil
#             </a>
# </li>
# <li id="nav-list-link-886">
# <a class="main-menu-link" href="/rayon/mp3-mp4-et-son-numerique-51/ecouteurs-intra-auriculaires-sport-11252">
#                 Ecouteurs de sport
#             </a>
# </li>
# </ul>
# <div class="nav-new-list-title" id="nav-list-1856">
# <a class="main-menu-link" href="/rayon/jeux-et-consoles-43">JEUX ET CONSOLES</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-1857">
# <a class="main-menu-link" href="/rayon/jeux-et-consoles-43/ps5">
#                 PS5
#             </a>
# </li>
# <li id="nav-list-link-1858">
# <a class="main-menu-link" href="/rayon/jeux-et-consoles-43/ps4-488">
#                 PS4
#             </a>
# </li>
# <li id="nav-list-link-1859">
# <a class="main-menu-link" href="/rayon/jeux-et-consoles-43/xbox-series">
#                 Xbox Series
#             </a>
# </li>
# <li id="nav-list-link-1860">
# <a class="main-menu-link" href="/rayon/jeux-et-consoles-43/nintendo-switch-491">
#                 Nintendo Switch
#             </a>
# </li>
# <li id="nav-list-link-1862">
# <a class="main-menu-link" href="/rayon/jeux-et-consoles-43/manettes">
#                 Manette
#             </a>
# </li>
# <li id="nav-list-link-1866">
# <a class="main-menu-link nav-new-list-link-bold nav-new-link-color-green-heavy" href="/rayon/destockage-22/jeux-et-consoles-310">
#                 Seconde vie - Jeux et consoles
#             </a>
# </li>
# </ul>
# </div>
# <div class="nav-new-column nav-new-column-25" id="nav-column-341">
# <div class="nav-new-list-title" id="nav-list-342">
# <a class="main-menu-link" href="/rayon/sono-eclairage-soiree">SONO - ECLAIRAGE DE SOIREE</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-344">
# <a class="main-menu-link" href="/rayon/instruments-de-musique-39/home-studio-439">
#                 Home studio
#             </a>
# </li>
# <li id="nav-list-link-345">
# <a class="main-menu-link" href="/rayon/instruments-de-musique-39/equipement-dj-437">
#                 Matériel DJ
#             </a>
# </li>
# <li id="nav-list-link-346">
# <a class="main-menu-link" href="/rayon/instruments-de-musique-39/microphones-443">
#                 Microphone
#             </a>
# </li>
# <li id="nav-list-link-343">
# <a class="main-menu-link" href="/rayon/instruments-de-musique-39">
#                 Instruments de musique
#             </a>
# </li>
# <li id="nav-list-link-350">
# <a class="main-menu-link" href="/rayon/eclairage-de-soiree-24/effets-lumineux-340">
#                 Effet lumineux
#             </a>
# </li>
# <li id="nav-list-link-351">
# <a class="main-menu-link" href="/rayon/eclairage-de-soiree-24/projecteurs-343">
#                 Projecteur
#             </a>
# </li>
# <li id="nav-list-link-352">
# <a class="main-menu-link" href="/rayon/eclairage-de-soiree-24/machines-a-effets-341">
#                 Machine à effet
#             </a>
# </li>
# </ul>
# <div class="nav-new-list-title" id="nav-list-316">
# <a class="main-menu-link" href="/vitrine/hifi">ENCEINTE - HIFI</a>
# </div>
# <ul class="nav-new-list-link">
# <li id="nav-list-link-317">
# <a class="main-menu-link" href="/rayon/mp3-mp4-et-son-numerique-51/enceinte-bluetooth-108882">
#                 Enceinte Bluetooth
#             </a>
# </li>
# <li id="nav-list-link-890">
# <a class="main-menu-link" href="/rayon/hifi-38/multiroom-18562">
#                 Enceinte multiroom
#             </a>
# </li>
# <li id="nav-list-link-321">
# <a class="main-menu-link" href="/rayon/hifi-38/chaines-hifi-3764">
#                 Chaine-Hifi
#             </a>
# </li>
# <li id="nav-list-link-322">
# <a class="main-menu-link" href="/rayon/hifi-38/enceintes-hifi-3766">
#                 Enceinte Hifi
#             </a>
# </li>
# <li id="nav-list-link-323">
# <a class="main-menu-link" href="/rayon/hifi-38/platine-3769">
#                 Platine vinyle
#             </a>
# </li>
# <li id="nav-list-link-795">
# <a class="main-menu-link nav-new-list-link-bold nav-new-link-color-green-heavy" href="/rayon/mp3-mp4-et-son-numerique-51/occasions">
#                 Seconde vie - Son audio
#             </a>
# </li>
# </ul>
# </div>
# ...
# <a href="https://www.rueducommerce.fr/page/sitemap.html" title="Plan du site">Plan du site</a> <span>|</span>
# <a href="#" id="rgpd-show-footer">Contrôler vos cookies</a> <span>|</span>
# <a href="/info/criteres-de-classement-des-offres" title="Fonctionnement Galerie marchande">Fonctionnement Galerie marchande</a>
# </div>
# </div>
# <div id="footer__secure">
# <div class="nav">
# <a href="/info/mentions-legales" title="Informations légales">Mentions légales</a> <span>|</span>
# <a href="/info/mentions-legales/cgv" title="CGV">CGV Rue Du Commerce</a> <span>|</span>
# <a href="/info/mentions-legales/cgu-gm" title="CGU Galerie Marchande">CGU Galerie Marchande</a> <span>|</span>
# <a href="/info/mentions-legales/confidentialite" title="Données personnelles">Données personnelles</a> <span>|</span>
# <a href="/info/votre-avis-nous-interesse" title="Avis">Avis</a> <span>|</span>
# <a href="https://www.rueducommerce.fr/page/sitemap.html" title="Plan du site">Plan du site</a> <span>|</span>
# <a href="#" id="rgpd-show-footer">Contrôler vos cookies</a> <span>|</span>
# <a href="/info/criteres-de-classement-des-offres" title="Fonctionnement Galerie marchande">Fonctionnement Galerie marchande</a>
# </div>
# <div class="secure">
# <svg aria-hidden="true" fill="#666" height="27" viewbox="0 0 30 30" width="27">
# <path d="M21.831 11.922V7.477C21.831 3.905 18.958 1 15.427 1c-3.532 0-6.405 2.906-6.405 6.477v4.444h-4.27v11.302c0 3.023 2.613 5.777 5.481 5.777h10.122c3.062 0 4.892-2.937 4.892-5.777V11.921zM10.73 7.477c0-2.674 2.063-4.769 4.697-4.769 2.633 0 4.696 2.096 4.696 4.77v4.443H10.73V7.477zm12.809 15.746c0 2-1.191 4.07-3.184 4.07H10.234c-1.94 0-3.773-1.978-3.773-4.07V13.63H23.54zm-9.18-3.142v2.94a.853.853 0 1 0 1.708 0v-2.94a1.7 1.7 0 0 0 .855-1.47 1.708 1.708 0 0 0-3.416 0 1.7 1.7 0 0 0 .853 1.47z"></path>
# </svg>
# <span>Paiement sécurisé</span>
# </div>
# <div class="payment">
# <i class="m-tunnelFooter__icons -cb"></i>
# <i class="m-tunnelFooter__icons -visa"></i>
# <i class="m-tunnelFooter__icons -mastercard"></i>
# <i class="m-tunnelFooter__icons -amex"></i>
# <i class="m-tunnelFooter__icons -eBleue"></i>
# <i class="m-tunnelFooter__icons -paypal"></i>
# <i class="m-tunnelFooter__icons -quatrexcb"></i>
# <i class="m-tunnelFooter__icons -unEuro"></i>
# </div>
# </div>
# </footer>
# <div class="popup modal_content" id="popup-newsletter-register-process">
# <p class="h2" id="popup-newsletter-register-title">Inscription Newsletter Validée</p>
# <div class="infos loader">
# <img alt="loader" class="lazyload" data-src="/images/shopinvest/ajax-loader.gif" id="popup-newsletter-register-loader" src="/images/all/pixel.png" style="margin: auto"/>
# <p class="puce puce--infos" id="popup-newsletter-register-message-process">
#             Traitement en cours, merci de patienter.
#         </p>
# <p class="puce puce--infos" id="popup-newsletter-register-message"></p>
# </div>
# </div>
# <div class="popup modal_content" id="popup-newsletter-register-error-email">
# <p class="h2" id="popup-newsletter-register-title-error">Erreur</p>
# <div class="infos loader">
# <p class="popup-newsletter-register-message puce puce--infos">
#             L'email indiqué n'est pas correct
#         </p>
# </div>
# </div><div class="popup popup--500 mfp-hide" id="popup-wishlist">
# <p class="h2">Wishlist</p>
# <div class="infos">
# <p class="puce puce--check puce--infos">Cet article a bien été ajouté à vos articles préférés</p>
# </div>
# <a class="btn btn--prin" href="https://www.rueducommerce.fr/wishlist.html">Voir cet article dans votre wishlist</a>
# </div><div class="popup popup--600 mfp-hide" id="popup-error">
# <p class="h2">Erreur</p>
# <div class="infos">
# <p class="puce puce--infos">Cet article n'a pas été ajouté</p>
# </div>
# </div>
# <div class="popup popup--600 mfp-hide" id="popup-error-wishlist-length">
# <p class="h2">Erreur</p>
# <div class="infos">
# <p class="puce puce--infos">Votre Wishlist ne peut dépasser 50 produits</p>
# </div>
# </div>
# <div class="popup popup--600 mfp-hide" id="popup-cart-to-wishlist">
# <div class="infos">
# <p class="puce puce--infos">Votre article a bien été déplacé vers votre wishlist.</p>
# </div>
# </div><section class="popup product-flash mfp-hide" id="product-card"></section>
# <div class="popup mfp-hide" id="popup-waiting" style="text-align:center;">
# <p><div class="loader-box"><img alt="Veuillez patienter pendant le traitement." class="lazyload" data-src="/images/shopinvest/ajax-loader.gif" src="/images/all/pixel.png">
# <p>Veuillez patienter pendant le traitement.</p>
# </img></div></p>
# </div>
# <div class="popup modal_content" data-url-rgpd="https://www.rueducommerce.fr/rgpd" id="template-rgpd-index">
# <div class="rgpd">
# <div class="row" id="rgpd-head-links">
# <div class="col-6">
# <a id="rgpd-btn-index-continue">Continuer sans accepter</a>
# </div>
# <div class="col-6" id="rgpd-head-links-right">
# <a id="rgpd-btn-index-accept-link">Fermer et accepter</a>
# </div>
# </div>
# <div>
# <div class="rgpd-logo">
# <img alt="Logo Rue Du Commerce" class="lazyload" data-src="/images/rdc/new/Logo-RDC-1.svg" src="/images/all/pixel.png"/> </div>
# <div class="rgpd-title h3">Faites un choix pour vos données</div>
# </div>
# <p>Sur notre site, nous recueillons à chacune de vos visites des données vous concernant. Ces données nous permettent de vous proposer les offres et services les plus pertinents pour vous, de vous adresser, en direct ou via des partenaires, des communications et publicités personnalisées et de mesurer leur efficacité. Elles nous permettent également d'adapter le contenu de nos sites à vos préférences, de vous faciliter le partage de contenu sur les réseaux sociaux et de réaliser des statistiques.</p>
# <p>Vous pouvez paramétrer vos choix pour accepter les cookies ou vous y opposer si vous le souhaitez.</p>
# <p>Nous conservons votre choix pendant <strong>6 mois</strong>. Vous pouvez changer d'avis à tout moment en cliquant sur le lien <strong>contrôler mes cookies</strong> en bas de chaque page de notre site.</p>
# <p>Pour en savoir plus, consultez notre <a href="/info/mentions-legales/confidentialite#rgpd">politique de cookies</a>.</p>
# <div class="rgpd-buttons">
# <button class="btn btn--secondary" id="rgpd-btn-index-parameters">Réglages</button>
# <button class="btn btn--prin" id="rgpd-btn-index-accept">Tout accepter</button>
# </div>
# </div>
# </div>
# <div class="popup modal_content" id="template-rgpd-parameters">
# <div class="rgpd">
# <div>
# <div class="rgpd-logo">
# <img alt="Logo Rue Du Commerce" class="lazyload" data-src="/images/rdc/new/Logo-RDC-1.svg" src="/images/all/pixel.png"/> </div>
# <div class="rgpd-title h3">Faites un choix pour vos données</div>
# </div>
# <div class="rgpd-subtitle"><p>Lorsque vous naviguez sur notre site internet, des informations sont susceptibles d'être enregistrées ou lues dans votre terminal, sous réserve de vos choix.</p>
# <p>Pour en savoir plus, consultez notre <a href="/info/mentions-legales/confidentialite#rgpd">politique de cookies</a>.</p></div>
# <div class="rgpd-choice">
# <div class="rgpd-choice-title">Cookies de fonctionnalités</div>
# <div class="rgpd-choice-content" id="rgpd-choice-content-enable">Toujours actif</div>
# </div>
# <div class="rgpd-choice-description">Ces cookies sont indispensables pour naviguer sur le site et ne peuvent pas être désactivés dans nos systèmes. Ces cookies nous permettent notamment d'assurer la bonne réalisation des commandes.</div>
# <div class="rgpd-choice">
# <div class="rgpd-choice-title">Cookies de sécurité</div>
# <div class="rgpd-choice-content" id="rgpd-choice-content-enable">Toujours actif</div>
# </div>
# <div class="rgpd-choice-description">Ces cookies sont utilisés par notre partenaire cybersécurité. Ils sont indispensables pour assurer la sécurité des transactions (notamment dans le cadre de la lutte contre la fraude à la carte bancaire)</div>
# <div class="rgpd-choice">
# <div class="rgpd-choice-title">Cookies publicitaires</div>
# <div class="rgpd-choice-content">
# <input id="rgpd-ad-yes" name="rgpd-ad" type="radio" value="granted"/>
# <label for="rgpd-ad-yes">Oui</label>
# <input id="rgpd-ad-no" name="rgpd-ad" type="radio" value="denied"/>
# <label for="rgpd-ad-no">Non</label>
# </div>
# </div>
# <div class="rgpd-choice-description">Ces cookies sont utilisés pour effectuer le suivi des visites afin de proposer des publicités pertinentes. Des cookies de réseaux sociaux peuvent également être enregistrés par des tiers lorsque vous visitez notre site afin de proposer des publicités personnalisées.</div>
# <div class="rgpd-choice">
# <div class="rgpd-choice-title">Cookies de suivi de trafic</div>
# <div class="rgpd-choice-content">
# <input id="rgpd-analytics-yes" name="rgpd-analytics" type="radio" value="granted"/>
# <label for="rgpd-analytics-yes">Oui</label>
# <input id="rgpd-analytics-no" name="rgpd-analytics" type="radio" value="denied"/>
# <label for="rgpd-analytics-no">Non</label>
# </div>
# </div>
# <div class="rgpd-choice-description">Ces cookies nous permettent d'améliorer les fonctionnalités, la personnalisation de notre site et l'expérience utilisateur en recueillant notamment des données sur les visites réalisées sur le site. Ils peuvent être déposés par nos partenaires qui proposent des services additionnels sur les pages de notre site web ou par nous.</div>
# <div class="rgpd-choice">
# <div class="rgpd-choice-title">Cookies de personnalisation</div>
# <div class="rgpd-choice-content">
# <input id="rgpd-personalization-yes" name="rgpd-personalization" type="radio" value="granted"/>
# <label for="rgpd-personalization-yes">Oui</label>
# <input id="rgpd-personalization-no" name="rgpd-personalization" type="radio" value="denied"/>
# <label for="rgpd-personalization-no">Non</label>
# </div>
# </div>
# <div class="rgpd-choice-description">Ces cookies nous permettent d’afficher des recommandations qui peuvent vous intéresser sur nos sites et ceux de tiers et d'en mesurer les performances et l'efficacité. En cliquant sur "non" les recommandations seront moins pertinentes.</div>
# <div id="rgpd-buttons-help">Vous devez faire un choix pour chaque catégorie afin de valider vos choix.</div>
# <div class="rgpd-buttons">
# <div id="rgpd-link-partners"><a href="/info/mentions-legales/confidentialite#rgpd2">Liste des partenaires</a></div>
# <button class="btn btn--prin" id="rgpd-btn-parameters-accept">Tout accepter</button>
# <button class="btn btn--secondary" id="rgpd-btn-parameters-choices">Je valide mes choix</button>
# </div>
# </div>
# </div>
# <div class="popup popup--800 mfp-hide" id="popup-other"></div>
# <script src="https://www.rueducommerce.fr/build/js/product.js?id=2d5e2aa2bc0f7ae466c0db884c6a2cfe"></script>
# <script src="https://www.rueducommerce.fr/build/js/rdc.js?id=393272ae7309099ceee7f2d0aac06112"></script>
# <script type="text/javascript">
#         $(document).ready(function () {
#             if(typeof iFrameResize !== 'undefined'){
#                 iFrameResize({}, "#questions-answers-iframe");
#             }
#         });
#     </script>
# <script type="text/javascript">
#         var callCnet = function () {
#             try {
#                 $.ajax({
#                     type: 'post',
#                     url: 'https://www.rueducommerce.fr/cnet-api',
#                     data: { ean: product_ean, mf: product_brand, pn: product_brand_ref},
#                     success: function (data) {
#                         if (typeof data.data !== 'undefined' &&
#                             typeof data.data['ccs-inline-content'] !== 'undefined' &&
#                             typeof data.data['ccs-inline-content'].available !== 'undefined' &&
#                             data.data['ccs-inline-content'].available) {
#
#
#                             ccs_cc_args.push(['mf', product_brand]);
#                                                         ccs_cc_args.push(['pn', product_brand_ref ]);
#                                                         ccs_cc_args.push(['upcean', product_ean]);
#                             ccs_cc_args.push(['lang', 'fr']);
#                             ccs_cc_args.push(['market', 'FR']);
#
#                             (function () {
#                                 var o = ccs_cc_args; o.push(['_SKey', 'fb7c0964']); o.push(['_ZoneId', 'b512d3e821']);
#                                 var sc = document.createElement('script'); sc.type = 'text/javascript'; sc.async = true;
#                                 sc.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'cdn.cs.1worldsync.com/jsc/h1ws.js';
#                                 var n = document.getElementsByTagName('script')[0]; n.parentNode.insertBefore(sc, n);
#                             })();
#                         }
#                     }
#                 });
#             } catch(e){ }
#         };
#
#         //init for cnet
#         var ccs_cc_args = ccs_cc_args || [];
#
#         var product_ean = "0887961516449";
#         var product_brand = "Fisher Price";
#         var product_brand_ref = "FISHER-PRICE-FGW66";
#
#                     var distributor = "10589";
#             var language = "fr";
#             var headID = document.getElementsByTagName("head")[0];
#             var flixScript = document.createElement('script');
#             flixScript.type = 'text/javascript';
#             flixScript.async = true;
#             flixScript.setAttribute('data-flix-distributor', distributor);
#             flixScript.setAttribute('data-flix-language', language);
#             flixScript.setAttribute('data-flix-brand', product_brand);
#             flixScript.setAttribute('data-flix-ean', product_ean);
#             flixScript.setAttribute('data-flix-inpage', 'flix-inpage-description');
#             flixScript.setAttribute('data-flix-price', '');
#             headID.appendChild(flixScript);
#             flixScript.onload=function(){
#                 if (typeof(flixJsCallbacks)==="object"){
#                     flixJsCallbacks.setLoadCallback(function(){
#                         try {
#                                                     }catch(e){ }
#                     }, 'inpage');
#                     flixJsCallbacks.setLoadCallback(function(){
#                         callCnet();
#                     }, 'noshow');
#                 }
#             };
#             flixScript.src = '//media.flixfacts.com/js/loader.js';
#             </script>
# <script type="text/javascript">
#         $('.rent-wrapper .btn-rent-product').on('click', function (e) {
#             e.preventDefault();
#             $.ajax({
#                 url: $(this).data('url'),
#                 method: "post",
#                 data: $(this).data('params'),
#                 dataType: "json",
#                 beforeSend: function(){
#                     $.magnificPopup.open({items: {src: '#popup-waiting'},type: 'inline', modal: true });
#                 },
#                 success: function(res){
#                     $.magnificPopup.close();
#                     $('#popup-rent-container').html(res);
#                     $.magnificPopup.open({items: {src: '#popup-rent'},type: 'inline'}, 0);
#                 }
#             });
#         });
#         $(document).on('click', '#popup-rent .rent-delivery', function () {
#             window.location.href = $(this).data('url');
#         });
#     </script>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KV4GH4N" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div aria-hidden="true" class="modal micromodal-slide" id="modalTpl">
# <div class="modal__overlay" data-micromodal-close="" tabindex="-1">
# <div aria-labelledby="modalTpl-title" aria-modal="true" class="modal__container" role="dialog">
# <main class="modal__content" id="modalTpl-content-container">
# <button aria-label="Close modal" class="modal__close" data-micromodal-close="" id="modalTpl-close-cross"></button>
# <div id="modalTpl-content"></div>
# </main>
# </div>
# </div>
# </div>
# <div class="overlay modal_content" id="modal-waiting"><p><div class="loader-box"><img alt="Veuillez patienter pendant le traitement." class="lazyload" data-src="/images/shopinvest/ajax-loader.gif" src="/images/all/pixel.png">
# <p>Veuillez patienter pendant le traitement.</p>
# </img></div></p></div></body>
# </html>

# %%
get_title(new_soup)
# Out:
# 'LE TELEPHONE ANIME - FGW66'

# %%
rueducommerce
# Out:
#                                                 title   price rating  reviews  \
# 0   Sony Xperia Z2 - Qualcomm snapdragon - 16 Go -...  248,90         39 Avis
# 1                         Crosscall Crosscall Core-X5  440,32
# 2   SAMSUNG Smartphone Galaxy S22 5G Noir EE 8 Go ...
# 3   doro - téléphone duo sans fil mains-libres dec...   54,89
# 4                           DESIGNATION REF PHILIPS42  111,91
# 5                           DESIGNATION REF PHILIPS43  105,02
# 6                          3S 850VA 510W ONDULEUR OFF
# 7   Téléphone sans fil Senior Doro PhoneEasy® 100w...   61,79
# 8   Prise parafoudre 8 prises + Protection Vidéo +...
# 9   Adaptateur USB WiFi bi-bande AC 600 Mbps à gai...
# 11                      Nokia 8110 4G Noir Double SIM
# 14             2,4'' QVGA - 4G - 4 Go - Kai OS - IP52                  2 Avis
# 15             2,4"" QVGA - 4G - 4 Go - Kai OS - IP52                  1 Avis
# 16  Multiprise/Parafoudre - Eaton Protection Box 8...                  1 Avis
# 18                             20h d'autonomie - Noir                  4 Avis
# 20  18h d'autonomie en communication - 200h en vei...   80,75          6 Avis
# 23                                   18 h d'autonomie                  2 Avis
# 25      Téléphone 1,8"" QQVGA - 2G - 8Mo - Nokia S30+   36,09          2 Avis
# 26                                     Spider X4 Noir  140,16          1 Avis
# 27                                216 DS RM 1187 Noir  159,95          1 Avis
# 28                          3310 - Double SIM - Jaune                  2 Avis
# 29                           3310 - Double SIM - Gris   79,31          1 Avis
# 31                                CLE A CHOC MICHELIN                  1 Avis
# 32                Téléphone sans fil AS405A Duo Blanc                  9 Avis
# 33                   Téléphone filaire sans répondeur                  2 Avis
# 34                              105 Double Sim - Noir                  2 Avis
# 36  Realme 9 5G 64GB Téléphone portable Meteor Noi...
# 38  SAMSUNG Smartphone Galaxy S22+ 5G Blanc 8 Go 1...  632,10
# 40                              TCL 30 64GB MUSE BLUE
# 42  Maxcom MM42D - Téléphone fixe avec carte SIM 4...  118,22          2 Avis
# 45  SAMSUNG Smartphone Galaxy S22 ULTRA 5G VERT 12...  758,36
# 47            APPLE iPhone 13 Pro Max 128GB Silver DE
# 48  Montre Connectée Android GPS 4G 1.54" Smartwat...   97,18
# 49                                     Doro Doro 2404
# 52  3.35"" - Wifi - Bluetooth 4.0 - Raccourci What...
# 58  Motorola Téléphone portable Moto G52 128 Go Gr...
# 59                         LE TELEPHONE ANIME - FGW66   20,36          1 Avis
#
#      availability
# 0   Not Available
# 1   Not Available
# 2   Not Available
# 3   Not Available
# 4   Not Available
# 5   Not Available
# 6   Not Available
# 7   Not Available
# 8   Not Available
# 9   Not Available
# 11  Not Available
# 14  Not Available
# 15  Not Available
# 16  Not Available
# 18  Not Available
# 20  Not Available
# 23  Not Available
# 25  Not Available
# 26  Not Available
# 27  Not Available
# 28  Not Available
# 29  Not Available
# 31  Not Available
# 32  Not Available
# 33  Not Available
# 34  Not Available
# 36  Not Available
# 38  Not Available
# 40  Not Available
# 42  Not Available
# 45  Not Available
# 47  Not Available
# 48  Not Available
# 49  Not Available
# 52  Not Available
# 58  Not Available
# 59  Not Available
